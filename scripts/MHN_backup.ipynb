# %%
import numpy as np
import scipy.io
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.keras.layers import Input, Dense, Lambda
from tensorflow.keras import Model
from tensorflow.keras.initializers import RandomNormal, RandomUniform
from tensorflow.keras.optimizers import Adam
# Out:
# /home/dima/miniconda3/lib/python3.7/site-packages/tensorflow_addons/utils/ensure_tf_install.py:67: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.4.0 and strictly below 2.7.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   UserWarning,

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
mat = scipy.io.loadmat('/REMOTE/AM_RNN/mnist_all.mat')
L = 28
MS = 8
c = 1 

Kx = 6
Ky = 6
N1 = 784
N2 = Kx*Ky

Nc = 10
Ns = 60000

mu = 0.01
sigma = 0.01
N_steps = 3

beta = 1.
R0 = 3 

batch_size = 500
eps = 0.02
N_ep = 10000

tau = 1.0
dt = 0.2

M=np.zeros((0,N1))
for i in range(Nc):
    M = np.concatenate((M, mat['train'+str(i)]), axis=0)
M = M/255.

# %%
class MHN_WITH_1_HIDDEN_LAYER(tf.keras.layers.Layer):
    def __init__(self, N1=N1, N2=N2, c=c, **kwargs):
        super().__init__(**kwargs)
        self.N1 = N1
        self.N2 = N2
        self.c = c
        

    def build(self, input_shape):
        self.kernel = self.add_weight(
            "kernel",
            shape=[self.N1, self.N2],
            initializer=RandomNormal(mean=mu, stddev=sigma, seed=None)
        )
        self.beta = self.add_weight(
            "beta",
            shape=[1, 1],
            initializer=RandomNormal(mean=beta, stddev=0.01, seed=None)
        )
        self.R = self.add_weight(
            "R",
            shape=[1, 1],
            initializer=RandomNormal(mean=R0, stddev=0.01, seed=None)
        )
        self.alpha = self.add_weight(
            "alpha",
            shape=[1, 1],
            initializer=RandomNormal(mean=dt/tau, stddev=0.01, seed=None)
        )
        
        super().build(input_shape)

    def call(self, v, mask):
        nc = tf.sqrt(tf.reduce_sum(tf.square(self.kernel), axis=[0]))
        Mem = self.kernel/nc*self.R
        
        h = tf.matmul(v,Mem)
        SM = tf.nn.softmax(self.beta*h)
        U = tf.matmul(SM, tf.transpose(Mem)) - v
        return [v + self.alpha*U*mask, SM]

# %%
input_mask = Input(shape=[L*L*c])
input1 = Input(shape=[L*L*c])
MHN_cell = MHN_WITH_1_HIDDEN_LAYER(N1, N2)

x, SM = MHN_cell(input1, input_mask)
for _ in range(N_steps-1):
    x, SM = MHN_cell(x, input_mask)
        
model = Model(inputs=[input1, input_mask], outputs=x)

# %%
tf.keras.utils.plot_model(model)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 784)]        0           []
#
#  input_1 (InputLayer)           [(None, 784)]        0           []
#
#  mhn_with_1_hidden_layer (MHN_W  [(None, 784),       28227       ['input_2[0][0]',
#  ITH_1_HIDDEN_LAYER)             (None, 36)]                      'input_1[0][0]',
#                                                                   'mhn_with_1_hidden_layer[0][0]',
#                                                                   'input_1[0][0]',
#                                                                   'mhn_with_1_hidden_layer[1][0]',
#                                                                   'input_1[0][0]']
#
# ==================================================================================================
# Total params: 28,227
# Trainable params: 28,227
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
optimizer = Adam(learning_rate=eps)

train_dataset = tf.data.Dataset.from_tensor_slices((M, M))
train_dataset = train_dataset.shuffle(Ns).batch(batch_size)

# %%
def print_status_bar(iteration, total, loss, metrics=None):
    metrics = ' - '.join(["{}: {:.4f}".format('loss', m) for m in [loss] + (metrics or [])])
    end = '' if iteration < total else '\n'
    print('\r{}/{} - '.format(iteration, total) + metrics, end=end)

# %%
def draw_weights(fig, synapses, Kx, Ky):
    fig.clf()
    yy=0
    HM=np.zeros((L*Ky,L*Kx))
    for y in range(Ky):
        for x in range(Kx):
            HM[y*L:(y+1)*L,x*L:(x+1)*L]=synapses[yy,:].reshape(L,L)
            yy += 1

    nc=np.amax(np.absolute(HM))
    im=plt.imshow(HM,cmap='bwr',vmin=-nc,vmax=nc)
    fig.colorbar(im,ticks=[np.amin(HM), 0, np.amax(HM)])
    plt.axis('off')
    fig.canvas.draw()

# %%
def mean_squared_error(y_true, y_pred):
    loss = tf.reduce_mean(tf.square(y_true-y_pred))*L*L/(MS*MS)
    return loss

# %%
# %matplotlib inline
# %matplotlib notebook
fig=plt.figure(figsize=(10,10))

for epoch in range(1, N_ep+1):
    print(f'Epoch {epoch}/{N_ep}')

    for step, (x_train, y_train) in enumerate(train_dataset):
        # masking training data
        x_train = tf.cast(tf.reshape(x_train,[-1,L,L,1]),dtype=tf.float32)
        y_train = tf.cast(y_train,dtype=tf.float32)
        x_train_masked = tfa.image.random_cutout(x_train, (MS, MS), constant_values=-1.)
        mask = 1. - tf.cast(tf.equal(x_train, x_train_masked), dtype=tf.float32)
        x_train_masked = x_train*tf.cast(1.0-mask, dtype=tf.float32)
        x_train_masked = tf.reshape(x_train_masked, [-1,L*L*c])
        mask = tf.cast(tf.reshape(mask, [-1,L*L*c]), dtype=tf.float32)
        
        # update weights
        with tf.GradientTape() as tape:
            y_pred = model([x_train_masked, mask])
            loss = mean_squared_error(y_train, y_pred)
        gradients = tape.gradient(loss, model.trainable_variables)
        optimizer.learning_rate.assign(eps)
        optimizer.apply_gradients(zip(gradients[:1], model.trainable_variables[:1]))
        
        optimizer.learning_rate.assign(eps/10)
        optimizer.apply_gradients(zip(gradients[1:], model.trainable_variables[1:]))

        for _ in range(1,len(model.trainable_variables)):
            model.trainable_variables[_].assign(tf.clip_by_value(model.trainable_variables[_], 0.01, 100))
        
        
        #print_status_bar
        print_status_bar((step+1)*batch_size, Ns, tf.sqrt(loss))

        # plot weights
        KS = model.layers[2].get_weights()[0]
        current_beta = model.layers[2].get_weights()[1][0][0]
        current_R = model.layers[2].get_weights()[2][0][0]
        current_alpha = model.layers[2].get_weights()[3][0][0]
    print('Current beta is: ', current_beta, ', current R is: ', current_R, ', current alpha is: ', current_alpha)
    draw_weights(fig, KS.T, Kx, Ky)
# Out:
# <img src="data:image/png;base64,..." width="720">
# Epoch 1/10000
# 60000/60000 - loss: 0.3558
# Current beta is:  1.2960664 , current R is:  3.362897 , current alpha is:  0.46468723
# Epoch 2/10000
# 60000/60000 - loss: 0.3313
# Current beta is:  1.471013 , current R is:  3.7023509 , current alpha is:  0.6317266
# Epoch 3/10000
# 60000/60000 - loss: 0.3366
# Current beta is:  1.5307918 , current R is:  4.0051627 , current alpha is:  0.7335175
# Epoch 4/10000
# 60000/60000 - loss: 0.3146
# Current beta is:  1.5096687 , current R is:  4.2785783 , current alpha is:  0.7988583
# Epoch 5/10000
# 60000/60000 - loss: 0.3120
# Current beta is:  1.442997 , current R is:  4.5336504 , current alpha is:  0.8442174
# Epoch 6/10000
# 60000/60000 - loss: 0.3116
# Current beta is:  1.3222193 , current R is:  4.7684827 , current alpha is:  0.8762334
# Epoch 7/10000
# 60000/60000 - loss: 0.3149
# Current beta is:  1.164429 , current R is:  4.989033 , current alpha is:  0.90053034
# Epoch 8/10000
# 60000/60000 - loss: 0.2891
# Current beta is:  0.98179436 , current R is:  5.1979656 , current alpha is:  0.9198203
# Epoch 9/10000
# 60000/60000 - loss: 0.3026
# Current beta is:  0.81038564 , current R is:  5.3973155 , current alpha is:  0.935906
# Epoch 10/10000
# 60000/60000 - loss: 0.2906
# Current beta is:  0.70142347 , current R is:  5.587364 , current alpha is:  0.9497978
# Epoch 11/10000
# 60000/60000 - loss: 0.2906
# Current beta is:  0.6292949 , current R is:  5.7660956 , current alpha is:  0.9615932
# Epoch 12/10000
# 60000/60000 - loss: 0.2947
# Current beta is:  0.56731814 , current R is:  5.9364324 , current alpha is:  0.9710064
# Epoch 13/10000
# 60000/60000 - loss: 0.2883
# Current beta is:  0.5214945 , current R is:  6.0999613 , current alpha is:  0.9796823
# Epoch 14/10000
# 60000/60000 - loss: 0.2855
# Current beta is:  0.4726052 , current R is:  6.2552533 , current alpha is:  0.9868602
# Epoch 15/10000
# 60000/60000 - loss: 0.2831
# Current beta is:  0.44339088 , current R is:  6.4102087 , current alpha is:  0.99416375
# Epoch 16/10000
# 60000/60000 - loss: 0.2831
# Current beta is:  0.42232507 , current R is:  6.556756 , current alpha is:  0.99904627
# Epoch 17/10000
# 60000/60000 - loss: 0.2849
# Current beta is:  0.40145248 , current R is:  6.698324 , current alpha is:  1.0039239
# Epoch 18/10000
# 60000/60000 - loss: 0.2858
# Current beta is:  0.37394243 , current R is:  6.8319407 , current alpha is:  1.008276
# Epoch 19/10000
# 60000/60000 - loss: 0.2749
# Current beta is:  0.3503275 , current R is:  6.959553 , current alpha is:  1.0105321
# Epoch 20/10000
# 60000/60000 - loss: 0.2738
# Current beta is:  0.33599263 , current R is:  7.0824943 , current alpha is:  1.0130152
# Epoch 21/10000
# 60000/60000 - loss: 0.2766
# Current beta is:  0.32533643 , current R is:  7.200038 , current alpha is:  1.0152452
# Epoch 22/10000
# 60000/60000 - loss: 0.2610
# Current beta is:  0.30463555 , current R is:  7.3128786 , current alpha is:  1.0155345
# Epoch 23/10000
# 60000/60000 - loss: 0.2825
# Current beta is:  0.28154048 , current R is:  7.420665 , current alpha is:  1.0151457
# Epoch 24/10000
# 60000/60000 - loss: 0.2696
# Current beta is:  0.27402294 , current R is:  7.52429 , current alpha is:  1.0132493
# Epoch 25/10000
# 60000/60000 - loss: 0.2648
# Current beta is:  0.2612549 , current R is:  7.6251717 , current alpha is:  1.0111705
# Epoch 26/10000
# 60000/60000 - loss: 0.2811
# Current beta is:  0.25432542 , current R is:  7.7215366 , current alpha is:  1.0075356
# Epoch 27/10000
# 60000/60000 - loss: 0.2756
# Current beta is:  0.24089801 , current R is:  7.815349 , current alpha is:  1.0032097
# Epoch 28/10000
# 60000/60000 - loss: 0.2710
# Current beta is:  0.2348922 , current R is:  7.906801 , current alpha is:  0.999467
# Epoch 29/10000
# 60000/60000 - loss: 0.2698
# Current beta is:  0.22194098 , current R is:  7.9973774 , current alpha is:  0.9946557
# Epoch 30/10000
# 55000/60000 - loss: 0.2684
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-d2f4c70ac5c1> in <module>
#      10         x_train = tf.cast(tf.reshape(x_train,[-1,L,L,1]),dtype=tf.float32)
#      11         y_train = tf.cast(y_train,dtype=tf.float32)
# ---> 12         x_train_masked = tfa.image.random_cutout(x_train, (MS, MS), constant_values=-1.)
#      13         mask = 1. - tf.cast(tf.equal(x_train, x_train_masked), dtype=tf.float32)
#      14         x_train_masked = x_train*tf.cast(1.0-mask, dtype=tf.float32)
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow_addons/image/cutout_ops.py in random_cutout(images, mask_size, constant_values, seed)
#      90
#      91     offset = tf.transpose([cutout_center_height, cutout_center_width], [1, 0])
# ---> 92     return cutout(images, mask_size, offset, constant_values)
#      93
#      94
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow_addons/image/cutout_ops.py in cutout(images, mask_size, offset, constant_values)
#     168             tf.range(tf.shape(cutout_shape)[0]),
#     169             fn_output_signature=tf.TensorSpec(
# --> 170                 shape=image_static_shape[1:-1], dtype=tf.bool
#     171             ),
#     172         )
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     614                   func.__module__, arg_name, arg_value, 'in a future version'
#     615                   if date is None else ('after %s' % date), instructions)
# --> 616       return func(*args, **kwargs)
#     617
#     618     doc = _add_deprecated_arg_value_notice_to_docstring(
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     546                 'in a future version' if date is None else ('after %s' % date),
#     547                 instructions)
# --> 548       return func(*args, **kwargs)
#     549
#     550     doc = _add_deprecated_arg_notice_to_docstring(
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow/python/ops/map_fn.py in map_fn_v2(fn, elems, dtype, parallel_iterations, back_prop, swap_memory, infer_shape, name, fn_output_signature)
#     643       swap_memory=swap_memory,
#     644       infer_shape=infer_shape,
# --> 645       name=name)
#     646
#     647
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     546                 'in a future version' if date is None else ('after %s' % date),
#     547                 instructions)
# --> 548       return func(*args, **kwargs)
#     549
#     550     doc = _add_deprecated_arg_notice_to_docstring(
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow/python/ops/map_fn.py in map_fn(fn, elems, dtype, parallel_iterations, back_prop, swap_memory, infer_shape, name, fn_output_signature)
#     499         back_prop=back_prop,
#     500         swap_memory=swap_memory,
# --> 501         maximum_iterations=n)
#     502     result_batchable = [r.stack() for r in r_a]
#     503
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow/python/ops/control_flow_ops.py in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2793                                               list(loop_vars))
#    2794       while cond(*loop_vars):
# -> 2795         loop_vars = body(*loop_vars)
#    2796         if try_to_pack and not isinstance(loop_vars, (list, _basetuple)):
#    2797           packed = True
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow/python/ops/control_flow_ops.py in <lambda>(i, lv)
#    2784         cond = lambda i, lv: (  # pylint: disable=g-long-lambda
#    2785             math_ops.logical_and(i < maximum_iterations, orig_cond(*lv)))
# -> 2786         body = lambda i, lv: (i + 1, orig_body(*lv))
#    2787       try_to_pack = False
#    2788
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow/python/ops/map_fn.py in compute(i, tas)
#     483       ag_ctx = autograph_ctx.control_status_ctx()
#     484       autographed_fn = autograph.tf_convert(fn, ag_ctx)
# --> 485       result_value = autographed_fn(elems_value)
#     486       nest.assert_same_structure(fn_output_signature or elems, result_value)
#     487       result_value_flat = nest.flatten(result_value)
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     687       try:
#     688         with conversion_ctx:
# --> 689           return converted_call(f, args, kwargs, options=options)
#     690       except Exception as e:  # pylint:disable=broad-except
#     691         if hasattr(e, 'ag_error_metadata'):
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     434     return _fall_back_unconverted(f, args, kwargs, options, e)
#     435
# --> 436   with StackTraceMapper(converted_f), tf_stack.CurrentModuleFilter():
#     437     try:
#     438       if kwargs is not None:
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow/python/util/tf_stack.py in __init__(self)
#     126         outer_f = f.f_back
#     127         if outer_f is not None:
# --> 128           filter_filename = inspect.getsourcefile(outer_f)
#     129       self._filename = filter_filename
#     130       # This may be called repeatedly: once on entry by the superclass, then by
#
# ~/miniconda3/lib/python3.7/inspect.py in getsourcefile(object)
#     691                  importlib.machinery.EXTENSION_SUFFIXES):
#     692         return None
# --> 693     if os.path.exists(filename):
#     694         return filename
#     695     # only return a non-existent filename if the module has a PEP 302 loader
#
# ~/miniconda3/lib/python3.7/genericpath.py in exists(path)
#      17     """Test whether a path exists.  Returns False for broken symbolic links"""
#      18     try:
# ---> 19         os.stat(path)
#      20     except OSError:
#      21         return False
#
# KeyboardInterrupt:

# %%
def draw_data(fig, dat, Kx, Ky):
    fig.clf()
    yy = 0
    HM = np.zeros((L*Ky,L*Kx))
    for y in range(Ky):
        for x in range(Kx):
            HM[y*L:(y+1)*L,x*L:(x+1)*L] = dat[yy,:].reshape(L,L)
            yy += 1

    nc = np.amax(np.absolute(HM))
    im = plt.imshow(HM,cmap='bwr',vmin=-nc,vmax=nc)
    fig.colorbar(im,ticks=[np.amin(HM), 0, np.amax(HM)])
    plt.axis('off')        
    fig.canvas.draw()

# %%
# %matplotlib inline
# %matplotlib notebook
fig=plt.figure(figsize=(10,10))
draw_data(fig, x_train_masked.numpy(), 10,10)

fig1=plt.figure(figsize=(10,10))
draw_data(fig1, y_train.numpy(), 10,10)

fig2=plt.figure(figsize=(10,10))
draw_data(fig2, y_pred.numpy(), 10,10)
# Out:
# <img src="data:image/png;base64,..." width="720">
# <img src="data:image/png;base64,..." width="720">
# <img src="data:image/png;base64,..." width="720">
